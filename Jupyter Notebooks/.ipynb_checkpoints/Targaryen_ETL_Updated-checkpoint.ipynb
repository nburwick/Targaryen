# %%
import pandas as pd
import numpy as np
import os

# %%
spotify_df = pd.read_csv(os.path.join('..','Resouces','genres_v2.csv'), delimiter=',', low_memory=False) 
long_df = pd.read_csv(os.path.join('..','Resouces','dataset-long.csv'), delimiter=',', low_memory=False, index_col=0)

# %%
spotify_df.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'genre', 'song_name', 'Unnamed: 0', 'title'],
#       dtype='object')

# %%
long_df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
spotify_df['genre'].value_counts()
# Out:
# Underground Rap    5875
# Dark Trap          4578
# Hiphop             3028
# trance             2999
# trap               2987
# techhouse          2975
# dnb                2966
# psytrance          2961
# techno             2956
# hardstyle          2936
# RnB                2099
# Trap Metal         1956
# Rap                1848
# Emo                1680
# Pop                 461
# Name: genre, dtype: int64

# %%
spotify_df['genre'].value_counts().index.tolist()
# Out:
# ['Underground Rap',
#  'Dark Trap',
#  'Hiphop',
#  'trance',
#  'trap',
#  'techhouse',
#  'dnb',
#  'psytrance',
#  'techno',
#  'hardstyle',
#  'RnB',
#  'Trap Metal',
#  'Rap',
#  'Emo',
#  'Pop']

# %%
long_df['track_genre'].value_counts()
# Out:
# acoustic             1000
# punk-rock            1000
# progressive-house    1000
# power-pop            1000
# pop                  1000
#                      ...
# folk                 1000
# emo                  1000
# electronic           1000
# electro              1000
# world-music          1000
# Name: track_genre, Length: 114, dtype: int64

# %%
nozero= long_df[long_df['popularity'] != 0]

# %%
nozero
# Out:
#                       track_id                 artists  \
# 0       5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1       4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2       1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3       6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4       5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                        ...                     ...
# 113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# ...

# %%
top800 = nozero.groupby('track_genre').apply(lambda x:x.nlargest(1000,'popularity')).reset_index(drop=True)

# %%
ddf = top800.groupby('track_genre').mean('popularity').sort_values('popularity', ascending=False).head(10)
ddf
# Out:
#              popularity    duration_ms  explicit  danceability    energy  \
# track_genre
# pop-film      59.401804  279741.055110  0.001002      0.597117  0.604308
# k-pop         59.204995  253482.944849  0.019771      0.640422  0.678770
# pop           58.161369  223594.191932  0.073350      0.632260  0.606142
# electro       57.905297  194520.834671  0.184591      0.650937  0.652485
# house         57.212730  193547.907873  0.130653      0.667605  0.740429
# chill         55.886458  168767.456250  0.173958      0.663425  0.424125
# metal         54.974843  258761.149686  0.153459      0.467845  0.831384
# edm           54.909091  192833.608150  0.112853      0.648417  0.741781
# indie-pop     54.867746  210102.524966  0.114710      0.599333  0.550565
# indie         54.474790  213350.707283  0.085434      0.598555  0.533182
#
#                   key   loudness      mode  speechiness  acousticness  \
# track_genre
# ...

# %% [raw]
# ['pop-film',
#  'k-pop',
#  'chill',
#  'sad',
#  'grunge',
#  'indian',
#  'anime',
#  'emo',
#  'sertanejo',
#  'pop']

# %%
filter_df = long_df.groupby('track_genre').mean('popularity').sort_values('popularity', ascending=False).head(10)
filter_df
# Out:
#              popularity  duration_ms  explicit  danceability    energy    key  \
# track_genre
# pop-film         59.283   279657.084     0.001      0.597146  0.604562  5.296
# k-pop            56.896   251277.169     0.049      0.647732  0.675654  5.328
# chill            53.651   169009.967     0.171      0.664346  0.426723  5.355
# sad              52.379   153800.880     0.450      0.692378  0.462470  5.365
# grunge           49.594   235579.061     0.072      0.457062  0.803290  5.255
# indian           49.539   245473.096     0.024      0.592273  0.567121  5.104
# anime            48.772   210204.076     0.055      0.537451  0.674108  5.332
# emo              48.128   189690.330     0.465      0.599321  0.669967  5.323
# sertanejo        47.866   204583.551     0.006      0.591647  0.710391  5.337
# pop              47.576   220672.776     0.074      0.630441  0.606437  5.412
#
#               loudness   mode  speechiness  acousticness  instrumentalness  \
# track_genre
# ...

# %%
filter_df = long_df.groupby('track_genre').mean('popularity').sort_values('popularity', ascending=False).head(10).index.tolist()

# %%
filter_df
# Out:
# ['pop-film',
#  'k-pop',
#  'chill',
#  'sad',
#  'grunge',
#  'indian',
#  'anime',
#  'emo',
#  'sertanejo',
#  'pop']

# %%
long_df_filtered = long_df[long_df['track_genre'].isin(filter_df)].reset_index(drop=True)

# %%
long_df_filtered
# Out:
#                     track_id                     artists  \
# 0     1gUAX2ImxDsB3YDcyxMXlB                          美波
# 1     1di1C0QI6Y92yZPYn6XYAZ                   KANA-BOON
# 2     3khEEPRyBeOUabbmOPJzAG               Kenshi Yonezu
# 3     1rN9QoVxw5U7TJkyaUR8C1  TK from Ling tosite sigure
# 4     23phSRwoMy48rwFpmuAP8q              Yoko Takahashi
# ...                      ...                         ...
# 9995  6L7edR8ePoAiOEthSAfeBD               Gerson Rufino
# 9996  0t9X7I69027UILQB4WYCai          Chico Rey & Paraná
# 9997  6nYIAevQfh7QhuQYXYLy50               Léo & Raphael
# 9998  7ALQOUgUrUifvmcGMCyvld                 Os Serranos
# 9999  23iyR47eBWtYZPWReCbAfy         João Paulo & Daniel
#
#                                             album_name  \
# 0                                              カワキヲアメク
# 1                                                 TIME
# 2                                            KICK BACK
# ...

# %%
filter_df
# Out:
# ['pop-film',
#  'k-pop',
#  'chill',
#  'sad',
#  'grunge',
#  'indian',
#  'anime',
#  'emo',
#  'sertanejo',
#  'pop']

# %%
long_df_filtered.to_csv(os.path.join('..', 'Outputs', 'cleaned_data.csv'),index=False)

# %%
long_df_filtered.to_json(os.path.join('..', 'Outputs', 'cleaned_data.json'),orient='records')

# %%
import json

# %%
js = list(json.load(open(os.path.join('..', 'Resouces', 'cleaned_data.json'))))

# %%
for i in js[:1]:
    print(i)
# Out:
# {'track_id': '1gUAX2ImxDsB3YDcyxMXlB', 'artists': '美波', 'album_name': 'カワキヲアメク', 'track_name': 'カワキヲアメク', 'popularity': 71, 'duration_ms': 251933, 'explicit': False, 'danceability': 0.541, 'energy': 0.846, 'key': 6, 'loudness': -2.729, 'mode': 0, 'speechiness': 0.0551, 'acousticness': 0.0122, 'instrumentalness': 0.000149, 'liveness': 0.163, 'valence': 0.524, 'tempo': 129.138, 'time_signature': 4, 'track_genre': 'anime'}
