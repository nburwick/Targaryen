# %% [markdown]
# # Targaryen ETL & MongoDB Cluster Initialization for Flask API
# #### Contributors: Nathon Burwick & Wen Chiou

# %%
# Import Dependencies for Notebook
from IPython.display import HTML
import pandas as pd
import json
import os
import numpy as np
from pprint import pprint
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth as auth
import time
from tqdm.notebook import tqdm

# %%
cid = "f9c962881a724177bd2168edffdbbfb1"
secret = "44868fdb925c48ffa4beb0fdb4b2a49c"
uri = "http://localhost:8080"
os.environ['SPOTIPY_CLIENT_ID'] = cid
os.environ['SPOTIPY_CLIENT_SECRET'] = secret
os.environ['SPOTIPY_REDIRECT_URI'] = uri
scope = "user-library-read"
oauth = auth(scope=scope)
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager, auth_manager=oauth)

# %%
def get_clean_csv_data():
    df = pd.read_csv(os.path.join('..','Outputs', 'cleaned_data.csv'), delimiter=',', low_memory=False)
    df_cleaned = df.drop_duplicates(['track_name', 'artists']).reset_index(drop=True)
    # for index, track in tqdm(df_cleaned.iterrows(), total=df_cleaned.shape[0]):
    #     artist = str(track['artists'])
    #     artist = artist.split(';')
    #     df_cleaned.at[index, 'artists'] = artist
    # df_cleaned.to_json(os.path.join('..', 'Outputs', 'cleaned_data.json'),orient='records')
    js_data = json.loads(df_cleaned.to_json(orient='records'))
    return df_cleaned, js_data

# %%
df, file_data = get_clean_csv_data()

# %%
df
# Out:
#                      track_id                        artists  \
# 0      5SuOikwiRyPMVoIQDJUgSV                ['Gen Hoshino']
# 1      4qPNDBW1i3p13qLCt0Ki3A               ['Ben Woodward']
# 2      1iJBSr7s7jYXzM8EGcbK5b  ['Ingrid Michaelson', 'ZAYN']
# 3      6lfxq3CG4xtTiEg7opyCyx               ['Kina Grannis']
# 4      5vjLSffimiIP26QG5WcN2K           ['Chord Overstreet']
# ...                       ...                            ...
# 81337  2C3TZjDRiAzdyViavDJ217              ['Rainy Lullaby']
# 81338  1hIz5L4IB9hN3WRYPOCGPw              ['Rainy Lullaby']
# 81339  6x8ZfSoqDjuNa5SVP5QjvX              ['Cesária Evora']
# 81340  2e6sXL2bYv4bSz6VTdnfLs           ['Michael W. Smith']
# 81341  2hETkH7cOfqmz3LqZDHZf5              ['Cesária Evora']
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# ...

# %%
pprint(file_data[0])
# Out:
# {'acousticness': 0.0322,
#  'album_name': 'Comedy',
#  'artists': "['Gen Hoshino']",
#  'danceability': 0.676,
#  'duration_ms': 230666,
#  'energy': 0.461,
#  'explicit': False,
#  'instrumentalness': 1.01e-06,
#  'key': 1,
#  'liveness': 0.358,
#  'loudness': -6.746,
#  'mode': 0,
#  'popularity': 73,
#  'speechiness': 0.143,
#  'tempo': 87.917,
#  'time_signature': 4,
#  'track_genre': 'acoustic',
#  'track_id': '5SuOikwiRyPMVoIQDJUgSV',
#  'track_name': 'Comedy',
#  'track_url': 'https://open.spotify.com/track/5SuOikwiRyPMVoIQDJUgSV',
#  'valence': 0.715}

# %%
# df[['track_name','artists','album_name','track_genre']].to_html(os.path.join('..','Outputs','pandas_table_test.html'),classes='table table-stripped')

# %%
count=0
for index, track in tqdm(df.iterrows(), total=df.shape[0]):
    if pd.isnull(track['track_url']) == True:
        count+=1
# Out:
#   0%|          | 0/81342 [00:00<?, ?it/s]

# %%
print(count)
# Out:
# 57734

# %%
result_test = spotify.search(f'track:Clarity')
print(result_test)

# %%
# %%time
not_found = 0
for index, track in tqdm(df.iterrows(), total=df.shape[0]):
    if pd.isnull(track['track_url']) == True:
        try:
            track_name = track['track_name']
            artist = track['artists'][0]
            result = spotify.search(f'track:{track_name} artist:{artist}')
            # pprint(result)
            url = result['tracks']['items'][0]['external_urls']['spotify']
            track_id = result['tracks']['items'][0]['id']
            # print(url)
            df.loc[index,'track_url'] = url
            df.loc[index, 'track_id'] = track_id
            time.sleep(0.5)
        except:
            not_found += 1
            df.loc[index,'track_url'] = None
    else:
        pass

# %%
print(f"{not_found} urls not found")

# %%
# df = df[~df['track_url'].isnull()]

# %%
df.to_json(os.path.join('..', 'Outputs', 'cleaned_data.json'),orient='records')

# %%
df.to_csv(os.path.join('..', 'Outputs', 'cleaned_data.csv'),index=False)
