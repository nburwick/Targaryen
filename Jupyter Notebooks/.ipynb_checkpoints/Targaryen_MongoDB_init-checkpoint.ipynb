# %% [markdown]
# # Targaryen ETL & MongoDB Cluster Initialization for Flask API
# #### Contributors: Nathon Burwick & Wen Chiou

# %%
# Import Dependencies for Notebook
from IPython.display import HTML
import pandas as pd
import json
import os
import numpy as np
from pprint import pprint
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth as auth
import time
from tqdm import tqdm
from IPython.display import clear_output

# %%
uri = 'mongodb+srv://nburwick:Swim_Fast01@cluster0.nvujnf4.mongodb.net/?retryWrites=true&w=majority'
server = ServerApi('1')
# Create a new client and connect to the server
mongo = MongoClient(uri, server_api=server)
database = mongo['targ_data']
targ_songs = database['song_data']

# %%
cid = "e5ee662214304d6fb8f821a2d7f4787e"
secret = "aa3cdc18f3034454a56b77f785c360ce"
uri = "http://localhost:8080"
os.environ['SPOTIPY_CLIENT_ID'] = cid
os.environ['SPOTIPY_CLIENT_SECRET'] = secret
os.environ['SPOTIPY_REDIRECT_URI'] = uri
scope = "user-library-read"
oauth = auth(scope=scope)
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
spotify = spotipy.Spotify(auth_manager=client_credentials_manager)

# %%
def get_clean_csv_data():
    genre_seeds = spotify.recommendation_genre_seeds()['genres']
    seeds = np.arange(1,len(genre_seeds) +1)
    genres_convert = dict(zip(genre_seeds, seeds))
    df = pd.read_csv(os.path.join('..','Resouces', 'dataset-long.csv'), delimiter=',', index_col=0, low_memory=False)
    df_cleaned = df.drop_duplicates(['track_id']).reset_index(drop=True)
    df_cleaned = df_cleaned.dropna(subset='track_name').reset_index(drop=True)
    df_cleaned['track_url'] = None
    df_cleaned['genre_seed'] = None
    for index, track in tqdm(df_cleaned.iterrows(), total=df_cleaned.shape[0]):
        genre = track['track_genre']
        df_cleaned.at[index, 'genre_seed'] = genres_convert[genre]
        df_cleaned.at[index, 'artists'] = track['artists'].split(';')
    songs_in_mongo = list(targ_songs.find({}))
    mongo_df = pd.json_normalize(songs_in_mongo)
    mongo_df.drop(columns='_id', inplace=True, errors='ignore')
    df_cleaned.update(mongo_df)
    df_cleaned.to_json(os.path.join('..', 'Outputs', 'cleaned_data.json'),orient='records')
    js_data = json.loads(df_cleaned.to_json(orient='records'))
    return df_cleaned, js_data, mongo_df

# %%
df, file_data , mongo_df = get_clean_csv_data()
# Out:
# 100%|██████████| 81341/81341 [00:01<00:00, 41179.58it/s]

# %%
df
# Out:
#                      track_id                    artists  \
# 0      5SuOikwiRyPMVoIQDJUgSV              [Gen Hoshino]
# 1      4qPNDBW1i3p13qLCt0Ki3A             [Ben Woodward]
# 2      1iJBSr7s7jYXzM8EGcbK5b  [Ingrid Michaelson, ZAYN]
# 3      6lfxq3CG4xtTiEg7opyCyx             [Kina Grannis]
# 4      5vjLSffimiIP26QG5WcN2K         [Chord Overstreet]
# ...                       ...                        ...
# 81336  2C3TZjDRiAzdyViavDJ217            [Rainy Lullaby]
# 81337  1hIz5L4IB9hN3WRYPOCGPw            [Rainy Lullaby]
# 81338  6x8ZfSoqDjuNa5SVP5QjvX            [Cesária Evora]
# 81339  2e6sXL2bYv4bSz6VTdnfLs         [Michael W. Smith]
# 81340  2hETkH7cOfqmz3LqZDHZf5            [Cesária Evora]
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# 3      Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                Hold On
# ...                                                  ...
# 81336  #mindfulness - Soft Rain for Mindful Meditatio...
# 81337  #mindfulness - Soft Rain for Mindful Meditatio...
# 81338                                            Best Of
# 81339                                  Change Your World
# 81340                                     Miss Perfumado
#
#                        track_name  popularity  duration_ms explicit  \
# 0                          Comedy        73.0     230667.0    False
# 1                Ghost - Acoustic        55.0     149610.0    False
# 2                  To Begin Again        57.0     210827.0    False
# 3      Can't Help Falling In Love        71.0     201933.0    False
# 4                         Hold On        82.0     198853.0    False
# ...                           ...         ...          ...      ...
# 81336         Sleep My Little Boy        21.0     384999.0    False
# 81337            Water Into Light        22.0     385000.0    False
# 81338              Miss Perfumado        22.0     271466.0    False
# 81339                     Friends        41.0     283893.0    False
# 81340                   Barbincor        22.0     241826.0    False
#
#        danceability  energy  key  ...  speechiness  acousticness  \
# 0             0.676  0.4610  1.0  ...       0.1430        0.0322
# 1             0.420  0.1660  1.0  ...       0.0763        0.9240
# 2             0.438  0.3590  0.0  ...       0.0557        0.2100
# 3             0.266  0.0596  0.0  ...       0.0363        0.9050
# 4             0.618  0.4430  2.0  ...       0.0526        0.4690
# ...             ...     ...  ...  ...          ...           ...
# 81336         0.172  0.2350  5.0  ...       0.0422        0.6400
# 81337         0.174  0.1170  0.0  ...       0.0401        0.9940
# 81338         0.629  0.3290  0.0  ...       0.0420        0.8670
# 81339         0.587  0.5060  7.0  ...       0.0297        0.3810
# 81340         0.526  0.4870  1.0  ...       0.0725        0.6810
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 0              0.000001    0.3580   0.7150   87.917             4.0
# 1              0.000006    0.1010   0.2670   77.489             4.0
# 2              0.000000    0.1170   0.1200   76.332             4.0
# 3              0.000071    0.1320   0.1430  181.740             3.0
# 4              0.000000    0.0829   0.1670  119.949             4.0
# ...                 ...       ...      ...      ...             ...
# 81336          0.928000    0.0863   0.0339  125.995             5.0
# 81337          0.976000    0.1050   0.0350   85.239             4.0
# 81338          0.000000    0.0839   0.7430  132.378             4.0
# 81339          0.000000    0.2700   0.4130  135.960             4.0
# 81340          0.000000    0.0893   0.7080   79.198             4.0
#
#        track_genre                                          track_url  \
# 0         acoustic  https://open.spotify.com/track/5SuOikwiRyPMVoI...
# 1         acoustic  https://open.spotify.com/track/4qPNDBW1i3p13qL...
# 2         acoustic  https://open.spotify.com/track/1iJBSr7s7jYXzM8...
# 3         acoustic  https://open.spotify.com/track/6lfxq3CG4xtTiEg...
# 4         acoustic  https://open.spotify.com/track/5vjLSffimiIP26Q...
# ...            ...                                                ...
# 81336  world-music                                               None
# 81337  world-music                                               None
# 81338  world-music                                               None
# 81339  world-music                                               None
# 81340  world-music                                               None
#
#       genre_seed
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# ...          ...
# 81336        126
# 81337        126
# 81338        126
# 81339        126
# 81340        126
#
# [81341 rows x 22 columns]

# %%
not_found = [] 
keep_traits = ['track_id', 'artists', 'track_name',
                       'popularity', 'duration_ms', 'explicit', 'danceability',
                       'energy', 'key', 'loudness', 'mode','speechiness',
                       'acousticness','instrumentalness','liveness','valence',
                       'tempo','time_signature','preview_url']

df = df[~(df.track_id.isin(mongo_df.track_id))].reset_index(drop=True)

# create chunks
chunks = [df.iloc[df.index[i:i + 50]] for i in range(0, df.shape[0], 50)]

# %%
print(len(chunks))
# Out:
# 1317

# %%
for chunk in tqdm(chunks, total=len(chunks)):    
    ids = chunk['track_id'].tolist()
    results_1 = spotify.tracks(ids)['tracks']
    time.sleep(0.5)
    for result in results_1:
        if result['id'] in ids:
            df_index = chunk[chunk['track_id'] == result['id']].index[0]
            df.at[df_index, 'album_name'] = result['album']['name']
            artists = []
            for art in result['artists'][:]:
                artists.append(art['name'])
            df.at[df_index, 'artists'] = artists
            df.at[df_index, 'track_url'] = result['external_urls']['spotify']
            df.at[df_index, 'preview_url'] = result['preview_url']
    results_2 = spotify.audio_features(ids)
    time.sleep(0.5)
    for result in results_2:
        if result['id'] in ids:
            df_index = chunk[chunk['track_id'] == result['id']].index[0]
            delete = set(result.keys()) - set(keep_traits)
            for trait in delete:
                del result[trait]
            for trait in result.keys():
                df.at[df_index, trait] = result[trait]
            push = json.loads(df.iloc[df_index].to_json())
            clear_output(wait=True)
            targ_songs.insert_one(push)
# Out:
#  21%|██        | 273/1317 [26:20<1:39:17,  5.71s/it]

# %%
# file = open(os.path.join('..', 'Outputs', 'cleaned_data.json'), "a")
for index, track in tqdm(df.iloc[:10].iterrows(), total=df.iloc[:1].shape[0]):
    if pd.isnull(track['track_url']):
        # try:
            clear_output(wait=True)
            track_id = track['track_id']
            result1 = spotify.track(track_id, market='US')
            pprint(result1)
            time.sleep(1)
            album = result1['album']['name']
            artists = []
            # print(result['artists'])
            for art in result1['artists'][:]:
                artists.append(art['name'])
            
            url = result1['external_urls']['spotify']
            # track_id = result['tracks']['items'][0]['id']
            pop = result1['popularity']
            result2 = spotify.audio_features(track_id)[0]
            pprint(result2)
            delete = set(result2.keys()) - set(keep_traits)
            
            for trait in delete:
                del result2[trait]
            
            for trait in result2.keys():
                df.loc[index, trait] = result2[trait]
                
            df.loc[index, 'album_name'] = album
            df.at[index, 'artists'] = artists
            df.loc[index,'track_url'] = url
            df.loc[index, 'popularity'] = pop
            push = json.loads(df.iloc[index].to_json())
            
            # pprint(push)
            targ_songs.insert_one(push)
            time.sleep(1)
        # except:
        #     not_found.append(json.loads(df.iloc[index].to_json()))
            
# df.to_json(os.path.join('..', 'Outputs', 'cleaned_data.json'),orient='records')
# Out:
# {'album': {'album_type': 'single',
#            'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1S2S00lgLYLGHWA44qGEUs'},
#                         'href': 'https://api.spotify.com/v1/artists/1S2S00lgLYLGHWA44qGEUs',
#                         'id': '1S2S00lgLYLGHWA44qGEUs',
#                         'name': 'Gen Hoshino',
#                         'type': 'artist',
#                         'uri': 'spotify:artist:1S2S00lgLYLGHWA44qGEUs'}],
#            'external_urls': {'spotify': 'https://open.spotify.com/album/41ERrwfzos93Xlf6hFBiDn'},
#            'href': 'https://api.spotify.com/v1/albums/41ERrwfzos93Xlf6hFBiDn',
#            'id': '41ERrwfzos93Xlf6hFBiDn',
#            'images': [{'height': 640,
#                        'url': 'https://i.scdn.co/image/ab67616d0000b27326573d555999566291e3b7a8',
#                        'width': 640},
#                       {'height': 300,
#                        'url': 'https://i.scdn.co/image/ab67616d00001e0226573d555999566291e3b7a8',
#                        'width': 300},
#                       {'height': 64,
#                        'url': 'https://i.scdn.co/image/ab67616d0000485126573d555999566291e3b7a8',
#                        'width': 64}],
#            'is_playable': True,
#            'name': 'Comedy',
#            'release_date': '2022-04-08',
#            'release_date_precision': 'day',
#            'total_tracks': 1,
#            'type': 'album',
#            'uri': 'spotify:album:41ERrwfzos93Xlf6hFBiDn'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1S2S00lgLYLGHWA44qGEUs'},
#               'href': 'https://api.spotify.com/v1/artists/1S2S00lgLYLGHWA44qGEUs',
#               'id': '1S2S00lgLYLGHWA44qGEUs',
#               'name': 'Gen Hoshino',
#               'type': 'artist',
#               'uri': 'spotify:artist:1S2S00lgLYLGHWA44qGEUs'}],
#  'disc_number': 1,
#  'duration_ms': 230666,
#  'explicit': False,
#  'external_ids': {'isrc': 'JPVI02200563'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/5SuOikwiRyPMVoIQDJUgSV'},
#  'href': 'https://api.spotify.com/v1/tracks/5SuOikwiRyPMVoIQDJUgSV',
#  'id': '5SuOikwiRyPMVoIQDJUgSV',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Comedy',
#  'popularity': 71,
#  'preview_url': 'https://p.scdn.co/mp3-preview/3ff56360de277b2cc32d713e0798d1ff63b8e8a8?cid=29ed89dc01c84a14bb29a6e1570405df',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:5SuOikwiRyPMVoIQDJUgSV'}
# {'acousticness': 0.0322,
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5SuOikwiRyPMVoIQDJUgSV',
#  'danceability': 0.676,
#  'duration_ms': 230667,
#  'energy': 0.461,
#  'id': '5SuOikwiRyPMVoIQDJUgSV',
#  'instrumentalness': 1.01e-06,
#  'key': 1,
#  'liveness': 0.358,
#  'loudness': -6.746,
#  'mode': 0,
#  'speechiness': 0.143,
#  'tempo': 87.917,
#  'time_signature': 4,
#  'track_href': 'https://api.spotify.com/v1/tracks/5SuOikwiRyPMVoIQDJUgSV',
#  'type': 'audio_features',
#  'uri': 'spotify:track:5SuOikwiRyPMVoIQDJUgSV',
#  'valence': 0.715}
# 100%|██████████| 1/1 [00:02<00:00,  2.39s/it]

# %%
print(f"{len(not_found)} urls not found")
# Out:
# 0 urls not found

# %%
# def build_API_data(df):
#     data = df.copy()
#     data = data[~data['track_url'].isnull()]
#     data = data[['track_id', 'artists', 'track_name',
#                        'popularity', 'duration_ms', 'explicit', 'danceability',
#                        'energy', 'key', 'loudness', 'mode','speechiness',
#                        'acousticness','instrumentalness','liveness','valence',
#                        'tempo','time_signature']]
#     data.reset_index(drop=True, inplace=True)
#     data_json = json.loads(data.to_json(orient='records'))
#     return data_json

# %%
# file_data = build_API_data(df)


# print(f'There are {len(file_data)} entries in data')
# pprint(file_data[-1])

# %%
len(list(targ_songs.find({})))

# %%
# Drop Database for Jupyter Notebook Reruns
# database.drop_collection('song_data')
# Out:
# {'nIndexesWas': 1,
#  'ns': 'targ_data.song_data_v2',
#  'ok': 1.0,
#  '$clusterTime': {'clusterTime': Timestamp(1689708093, 87),
#   'signature': {'hash': b'k\x8f-\xefi\x06.\x871\xc2\x87\xdej)QK\x95\xc3\xa1\xd6',
#    'keyId': 7205268884167852039}},
#  'operationTime': Timestamp(1689708093, 86)}
