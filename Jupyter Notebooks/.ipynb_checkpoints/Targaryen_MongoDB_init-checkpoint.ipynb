# %%
import pandas as pd
import json
import os
import numpy as np
from pprint import pprint
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time

# %%
os.environ['SPOTIPY_CLIENT_ID'] = "99b3295c313d45088cb4f8fe0f8dbb81"
os.environ['SPOTIPY_CLIENT_SECRET'] = "ac4fa266a80d43e3beb6b31d2b88dcfb"
os.environ['OAUTH_TOKEN_URL'] = 'https://accounts.spotify.com/api/token'
spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

# %%
def build_API_data():
    file = open(os.path.join('..','Outputs', 'cleaned_data.json'),"r")
    data = json.load(file)
    df = pd.json_normalize(data)
    return df, data

# %%
df, file_data = build_API_data()

# %%
df
# Out:
#                     track_id      artists                     album_name  \
# 0     0DuWDLjriRPjDRoPgaCslY        Adele                             25
# 1     3di5hcvxxciiqwMH1jarhY        Adele                             21
# 2     6DEMMeWXfmFAXgDUMMzeg6        Adele                             25
# 3     0gplL1WMoJ6iYaPgMCL0gX        Adele                     Easy On Me
# 4     3bNv3VuUOKgrf5hu3YcuRo        Adele                             21
# ...                      ...          ...                            ...
# 8934  4DqNBM2oUr5R87cUd2E3P6       Josh A          LONELY VIBES (Deluxe)
# 8935  6HdrRVMieDZtv0vldfZxqg        Rarin                       Day Ones
# 8936  6hzTeCA93yeY8WZE0kW3ui        Powfu  some boring love stories pt 5
# 8937  7sFRIgzKlKRSfBDWUvtpwU     LoveJSan        Saddest Popstar to Live
# 8938  5Okrz6AYoHlzGRWLEeSrrX  Powfu;Jomie  some boring love stories pt 5
#
#                            track_name  popularity  duration_ms  explicit  \
# 0                    Love In The Dark          78       285935     False
# 1                Set Fire to the Rain          80       242973     False
# 2                           All I Ask          74       271800     False
# 3                          Easy On Me          85       224694     False
# 4                    Someone Like You          81       285240     False
# ...                               ...         ...          ...       ...
# 8934                             PTSD          41       121867     False
# 8935                         Day Ones          47       134913      True
# 8936              clash of the titans          42       110000     False
# 8937               I Got You Flowers!          49       154000      True
# 8938  throw it all away (feat. Jomie)          43       176202     False
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.331   0.341    9    -6.057     0       0.0309       0.52800
# 1            0.603   0.670    2    -3.882     0       0.0249       0.00408
# 2            0.591   0.280    4    -5.494     1       0.0283       0.88900
# 3            0.604   0.366    5    -7.519     1       0.0282       0.57800
# 4            0.556   0.319    9    -8.251     1       0.0281       0.89300
# ...            ...     ...  ...       ...   ...          ...           ...
# 8934         0.644   0.637    7    -7.922     1       0.0898       0.38200
# 8935         0.739   0.639    9    -8.636     1       0.2530       0.11900
# 8936         0.727   0.419    1    -8.334     1       0.1870       0.59500
# 8937         0.598   0.540    7    -6.199     1       0.0363       0.05040
# 8938         0.769   0.595    8    -7.605     1       0.0550       0.54800
#
#       instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0             0.000000    0.1090    0.152  109.821               4     british
# 1             0.000002    0.1120    0.446  107.993               4     british
# 2             0.000000    0.1240    0.348  141.916               4     british
# 3             0.000000    0.1330    0.130  141.981               4     british
# 4             0.000000    0.0996    0.294  135.187               4     british
# ...                ...       ...      ...      ...             ...         ...
# 8934          0.000000    0.1410    0.216   81.479               4         sad
# 8935          0.000000    0.1190    0.482  143.044               4         sad
# 8936          0.000000    0.1120    0.751  158.344               4         sad
# 8937          0.000144    0.2110    0.244  140.130               4         sad
# 8938          0.000000    0.0864    0.679  158.045               4         sad
#
# [8939 rows x 20 columns]

# %%
chunks = [file_data[i:i + 50] for i in range(0, len(file_data), 50)]

# %%
chunked_ids = [[track['track_id'] for track in chunk] for chunk in chunks]
print(len(chunked_ids[-1]))
# Out:
# 39

# %%
# %time
# test_chunk = chunked_ids[-2]

# %%
# for track in test_search['tracks']:
#     print({'track_id': track['id'],'name': track['name'], 'url': track['external_urls']['spotify'], 'popularity': track['popularity']})

# %%
# %time
# file_data = [dict(track, **{'track_url': spotify.track(track['track_id'])['external_urls']['spotify']}) for track in file_data]

# %%
urls = []
i = 0
for chunk in chunked_ids:

    results = spotify.tracks(chunk)
    i += 1
    print(i)
    
    results = results['tracks']
    result = [{'track_id': track['id'],'name': track['name'],
               'url': track['external_urls']['spotify'], 'popularity': track['popularity']} for track in results]
    print(result)
    urls.append(result)
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 i = 0
#       3 for chunk in chunked_ids:
# ----> 5     results = spotify.tracks(chunk)
#       6     i += 1
#       7     print(i)
#
# File ~/anaconda3/lib/python3.9/site-packages/spotipy/client.py:382, in Spotify.tracks(self, tracks, market)
#     374 """ returns a list of tracks given a list of track IDs, URIs, or URLs
#     375
#     376     Parameters:
#     377         - tracks - a list of spotify URIs, URLs or IDs. Maximum: 50 IDs.
#     378         - market - an ISO 3166-1 alpha-2 country code.
#     379 """
#     381 tlist = [self._get_id("track", t) for t in tracks]
# --> 382 return self._get("tracks/?ids=" + ",".join(tlist), market=market)
#
# File ~/anaconda3/lib/python3.9/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/spotipy/client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     262 logger.debug('Sending %s to %s with Params: %s Headers: %s and Body: %r ',
#     263              method, url, args.get("params"), headers, args.get('data'))
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#     272     results = response.json()
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:876, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     873     return response
#     875 response.drain_conn()
# --> 876 retries.sleep(response)
#     877 log.debug("Retry: %s", url)
#     878 return self.urlopen(
#     879     method,
#     880     url,
#    (...)
#     891     **response_kw
#     892 )
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py:428, in Retry.sleep(self, response)
#     419 """Sleep between retry attempts.
#     420
#     421 This method will respect a server's ``Retry-After`` response header
#    (...)
#     424 this method will return immediately.
#     425 """
#     427 if self.respect_retry_after_header and response:
# --> 428     slept = self.sleep_for_retry(response)
#     429     if slept:
#     430         return
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py:407, in Retry.sleep_for_retry(self, response)
#     405 retry_after = self.get_retry_after(response)
#     406 if retry_after:
# --> 407     time.sleep(retry_after)
#     408     return True
#     410 return False
#
# KeyboardInterrupt:
